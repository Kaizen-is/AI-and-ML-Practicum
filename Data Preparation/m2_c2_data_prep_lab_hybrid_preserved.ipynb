# %% [markdown]
# # Python Data Preparation Lab — Classroom Hybrid
# ## Module 2, Class 2 — NumPy & Pandas
#
# This version keeps the **original lab backbone** and adds an **in-class sync flow** for your lesson.
#
# ### In class we focus on:
# 1. NumPy intuition
# 2. Loading a dataset
# 3. Inspecting structure
# 4. Selecting columns
# 5. Filtering rows
# 6. Grouping and summarizing
#
# ### For homework / full lab we continue with:
# 1. Missing values
# 2. Duplicates
# 3. Date conversion
# 4. Derived customer features
# 5. Saving cleaned outputs
#
# > Goal: keep the **original lab strength**, but make the notebook easier to teach live with Darya's slides.

# %% [markdown]
# ## Start here
# - Open this notebook in Colab
# - For the live lesson, use `sample_superstore_lesson.csv`
# - For stronger homework practice later, use the full `SampleSuperstore.csv` from Kaggle
# - Run cells from top to bottom
# - If something breaks, do **not** panic — read the error and ask for help

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 0 — Load the dataset
#
# **Option A (classroom):** use `sample_superstore_lesson.csv` for the lesson.
#
# **Option B (full homework):** upload `SampleSuperstore.csv` from Kaggle.
#
# **Option C:** use your own path or mounted drive.

# %%
# Option A: Upload in Colab
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv('sample_superstore_lesson.csv')

# Option B: Full dataset from Kaggle
df = pd.read_csv('train.csv', index_col = 0)

# # Option C: Auto-try common filenames
# try:
#     df = pd.read_csv('sample_superstore_lesson.csv')
#     print('Loaded classroom lesson dataset: sample_superstore_lesson.csv')
# except FileNotFoundError:
#     df = pd.read_csv('SampleSuperstore.csv')
#     print('Loaded full dataset: SampleSuperstore.csv')

# print(df.head(3))

df.head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %% [markdown]
# ---
# # IN CLASS — Part 1: NumPy intuition
#
# NumPy is useful for **fast operations on arrays**.

# %%
arr = np.array([10, 20, 30, 40])

print("Array:", arr)
print("Type:", type(arr))
print("Shape:", arr.shape)
print("Doubled:", arr * 2)
print("Mean:", arr.mean())
print("Values > 25:", arr[arr > 25])
# Out:
# Array: [10 20 30 40]
# Type: <class 'numpy.ndarray'>
# Shape: (4,)
# Doubled: [20 40 60 80]
# Mean: 25.0
# Values > 25: [30 40]

# %%
# Mean with a for loop
numbers = [10, 20, 30, 40]

total = 0
count = 0

for num in numbers:
    total += num
    count += 1

mean_loop = total / count
print("Mean with for loop:", mean_loop)

# Mean with NumPy
numbers_np = np.array([10, 20, 30, 40])
mean_numpy = numbers_np.mean()
print("Mean with NumPy:", mean_numpy)
# Out:
# Mean with for loop: 25.0
# Mean with NumPy: 25.0

# %%
# Mini TODO
my_arr = np.array([5, 10, 15, 20])

print("Shape:", my_arr.shape)
print("Doubled:", my_arr * 2)
print("Values > 10:", my_arr[my_arr > 10])
# Out:
# Shape: (4,)
# Doubled: [10 20 30 40]
# Values > 10: [15 20]

# %% [markdown]
# ---
# # IN CLASS — Part 2: Pandas basics
#
# Now we move from arrays to **tables**.
# A Pandas **DataFrame** is like a programmable spreadsheet.

# %%
# First look at the table
df.head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 3       CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %%
# Shape = rows, columns
print(f"Shape: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Shape: 9800 rows, 17 columns

# %%
# Data types and non-null counts
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   str
#  1   Order Date     9800 non-null   str
#  2   Ship Date      9800 non-null   str
#  3   Ship Mode      9800 non-null   str
#  4   Customer ID    9800 non-null   str
#  5   Customer Name  9800 non-null   str
#  6   Segment        9800 non-null   str
#  7   Country        9800 non-null   str
#  8   City           9800 non-null   str
#  9   State          9800 non-null   str
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   str
#  12  Product ID     9800 non-null   str
#  13  Category       9800 non-null   str
#  14  Sub-Category   9800 non-null   str
#  15  Product Name   9800 non-null   str
#  16  Sales          9800 non-null   float64
# dtypes: float64(2), str(15)
# memory usage: 1.3 MB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#         Postal Code         Sales
# count   9789.000000   9800.000000
# mean   55273.322403    230.769059
# std    32041.223413    626.651875
# min     1040.000000      0.444000
# 25%    23223.000000     17.248000
# 50%    58103.000000     54.490000
# 75%    90008.000000    210.605000
# max    99301.000000  22638.480000

# %%
# Quick check for missing values
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ### Quick thinking pause
# Ask yourself:
# - How many rows and columns do we have?
# - What are the important columns?
# - Which columns are numerical?
# - Do we have missing values?

# %% [markdown]
# ---
# # IN CLASS — Part 3: Selecting columns

# %%
# One column
df["Sales"].head()
# Out:
# Row ID
# 1    261.9600
# 2    731.9400
# 3     14.6200
# 4    957.5775
# 5     22.3680
# Name: Sales, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9800 entries, 1 to 9800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9800 non-null   str
#  1   Order Date     9800 non-null   str
#  2   Ship Date      9800 non-null   str
#  3   Ship Mode      9800 non-null   str
#  4   Customer ID    9800 non-null   str
#  5   Customer Name  9800 non-null   str
#  6   Segment        9800 non-null   str
#  7   Country        9800 non-null   str
#  8   City           9800 non-null   str
#  9   State          9800 non-null   str
#  10  Postal Code    9789 non-null   float64
#  11  Region         9800 non-null   str
#  12  Product ID     9800 non-null   str
#  13  Category       9800 non-null   str
#  14  Sub-Category   9800 non-null   str
#  15  Product Name   9800 non-null   str
#  16  Sales          9800 non-null   float64
# dtypes: float64(2), str(15)
# memory usage: 1.3 MB

# %%
# Multiple columns
df[["City", "Sales"]].head()
# Out:
#                    City     Sales
# Row ID
# 1             Henderson  261.9600
# 2             Henderson  731.9400
# 3           Los Angeles   14.6200
# 4       Fort Lauderdale  957.5775
# 5       Fort Lauderdale   22.3680

# %% [markdown]
# Remember:
# - `df["Sales"]` -> one column
# - `df[["City", "Sales"]]` -> multiple columns

# %% [markdown]
# ---
# # IN CLASS — Part 4: Filtering rows

# %%
# Example 1: one condition
df[df["Region"] == "Central"].head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 15      US-2016-118983  22/11/2016  26/11/2016  Standard Class    HP-14815
# 16      US-2016-118983  22/11/2016  26/11/2016  Standard Class    HP-14815
# 17      CA-2015-105893  11/11/2015  18/11/2015  Standard Class    PK-19075
# 22      CA-2017-137330  09/12/2017  13/12/2017  Standard Class    KB-16585
# 23      CA-2017-137330  09/12/2017  13/12/2017  Standard Class    KB-16585
#
#         Customer Name      Segment        Country        City      State  \
# Row ID
# 15      Harold Pawlan  Home Office  United States  Fort Worth      Texas
# 16      Harold Pawlan  Home Office  United States  Fort Worth      Texas
# 17          Pete Kriz     Consumer  United States     Madison  Wisconsin
# 22          Ken Black    Corporate  United States     Fremont   Nebraska
# 23          Ken Black    Corporate  United States     Fremont   Nebraska
#
# ...

# %%
# Example 2: one numeric condition
df[df["Sales"] > 1000].head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 11      CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 25      CA-2016-106320  25/09/2016  30/09/2016  Standard Class    EB-13870
# 28      US-2016-150630  17/09/2016  21/09/2016  Standard Class    TB-21520
# 36      CA-2017-117590  08/12/2017  10/12/2017     First Class    GH-14485
# 55      CA-2017-105816  11/12/2017  17/12/2017  Standard Class    JM-15265
#
#           Customer Name    Segment        Country           City  \
# Row ID
# 11      Brosina Hoffman   Consumer  United States    Los Angeles
# 25          Emily Burns   Consumer  United States           Orem
# 28      Tracy Blumstein   Consumer  United States   Philadelphia
# 36            Gene Hale  Corporate  United States     Richardson
# 55       Janet Molinari  Corporate  United States  New York City
#
#                State  Postal Code   Region       Product ID    Category  \
# Row ID
# ...

# %%
# Example 3: combined conditions
df[(df["Sales"] > 1000) & (df["Category"] == "Technology")].head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 36      CA-2017-117590  08/12/2017  10/12/2017     First Class    GH-14485
# 55      CA-2017-105816  11/12/2017  17/12/2017  Standard Class    JM-15265
# 166     CA-2015-139892  08/09/2015  12/09/2015  Standard Class    BM-11140
# 216     CA-2016-146262  02/01/2016  09/01/2016  Standard Class    VW-21775
# 252     CA-2017-145625  11/09/2017  17/09/2017  Standard Class    KC-16540
#
#           Customer Name    Segment        Country           City       State  \
# Row ID
# 36            Gene Hale  Corporate  United States     Richardson       Texas
# 55       Janet Molinari  Corporate  United States  New York City    New York
# 166        Becky Martin   Consumer  United States    San Antonio       Texas
# 216     Victoria Wilson  Corporate  United States         Medina        Ohio
# 252     Kelly Collister   Consumer  United States      San Diego  California
#
# ...

# %% [markdown]
# Important:
# - Use `&`, not `and`
# - Put each condition in parentheses

# %% [markdown]
# ---
# # IN CLASS — Part 5: Grouping and summarizing

# %%
# Mean sales by category
df.groupby("Category")["Sales"].mean()
# Out:
# Category
# Furniture          350.653790
# Office Supplies    119.381001
# Technology         456.401474
# Name: Sales, dtype: float64

# %%
# Total sales by region
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
# Number of orders by ship mode
df.groupby("Ship Mode")["Order ID"].count()
# Out:
# Ship Mode
# First Class       1501
# Same Day           538
# Second Class      1902
# Standard Class    5859
# Name: Order ID, dtype: int64

# %%
# Quick preview of missing values again
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Postal Code    11
# dtype: int64

# %% [markdown]
# ## End of in-class core flow
#
# If students understand these ideas, the lesson worked:
# 1. NumPy = arrays
# 2. Pandas = tables
# 3. First data workflow = load -> inspect -> filter -> summarize
#
# > Important: the **original notebook was stronger as a full homework lab**.
# > So below we keep the original cleaning / feature engineering backbone almost unchanged.
# > For best results after class, rerun the same notebook with the full `SampleSuperstore.csv`.

# %% [markdown]
# ---
# # HOMEWORK / FULL LAB CONTINUES HERE
#
# Below is the **original lab logic** preserved for deeper work:
# - handle missing values properly
# - remove duplicates
# - convert dates
# - create customer-level features
# - save cleaned outputs
#
# For richer statistics and more realistic outputs, use the **full Superstore dataset** when possible.

# %% [markdown]
# ---
# ## Task 2: Missing Values (pre-built)
#
# Check which columns have missing values and how many.

# %%
# Count missing values per column
missing = df.isnull().sum()
missing_pct = (df.isnull().sum() / len(df) * 100).round(2)

missing_report = pd.DataFrame({
    'missing_count': missing,
    'missing_pct': missing_pct
})

# Show only columns with missing values
missing_report[missing_report['missing_count'] > 0]
# Out:
#              missing_count  missing_pct
# Postal Code             11         0.11

# %%
# Fill missing numerical values with median (robust to outliers)
numerical_cols = df.select_dtypes(include=[np.number]).columns
for col in numerical_cols:
    if df[col].isnull().sum() > 0:
        median_val = df[col].median()
        df[col].fillna(median_val, inplace=True)
        print(f"Filled {col} missing values with median: {median_val}")

# Fill missing categorical values with mode
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    if df[col].isnull().sum() > 0:
        mode_val = df[col].mode()[0]
        df[col].fillna(mode_val, inplace=True)
        print(f"Filled {col} missing values with mode: {mode_val}")

# Verify: no more missing values
print(f"\nTotal missing values remaining: {df.isnull().sum().sum()}")
# Out:
# Filled Postal Code missing values with median: 58103.0
#
# Total missing values remaining: 11
# C:\Users\user\AppData\Local\Temp\ipykernel_25096\1003425343.py:6: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].fillna(median_val, inplace=True)
# ...

# %% [markdown]
# ---
# ## Task 3: Remove Duplicates (pre-built)

# %%
# Check for duplicates
n_duplicates = df.duplicated().sum()
print(f"Duplicate rows found: {n_duplicates}")

# Remove duplicates
if n_duplicates > 0:
    df = df.drop_duplicates()
    print(f"After removal: {df.shape[0]} rows remain")
else:
    print("No duplicates to remove.")
# Out:
# Duplicate rows found: 1
# After removal: 9799 rows remain

# %% [markdown]
# ---
# ## Task 4: Convert Date Columns (TODO)
#
# The `Order Date` and `Ship Date` columns are stored as strings. Convert them to proper datetime objects.
#
# Hint: Use `pd.to_datetime()`. After conversion, verify with `.dtypes`.

# %%
# Check current types of date columns
print("Before conversion:")
for col in df.columns:
    if 'date' in col.lower() or 'Date' in col:
        print(f"  {col}: {df[col].dtype}")
        print(f"  Sample value: {df[col].iloc[0]}")
# Out:
# Before conversion:
#   Order Date: str
#   Sample value: 08/11/2017
#   Ship Date: str
#   Sample value: 11/11/2017

# %%
# TODO: Convert date columns to datetime
# Look at the column names printed above and convert them.
# The column names may vary depending on the dataset version.
#
# Example pattern:
# df['Column Name'] = pd.to_datetime(df['Column Name'])

# Your code here:
df["Order Date"] = pd.to_datetime(df["Order Date"], format="%d/%m/%Y")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], format="%d/%m/%Y")

# %%
# TODO: Verify the conversion worked
# Print dtypes for the date columns to confirm they are datetime64

# Your code here:
print(df['Order Date'].dtype)
print(df['Ship Date'].dtype)
# Out:
# datetime64[us]
# datetime64[us]

# %% [markdown]
# ---
# ## Task 5: Derived Features (TODO)
#
# Create customer-level summary features. These are the building blocks for customer segmentation (Activity 4).
#
# You need to create:
# - **total_spending**: Total sales per customer
# - **order_frequency**: Number of orders per customer
# - **avg_order_value**: Average sales amount per order per customer
#
# Hint: Use `df.groupby('Customer ID')` (or whatever the customer ID column is named).

# %%
# First, identify the right column names
print("All columns:")
for col in df.columns:
    print(f"  {col}")
# Out:
# All columns:
#   Order ID
#   Order Date
#   Ship Date
#   Ship Mode
#   Customer ID
#   Customer Name
#   Segment
#   Country
#   City
#   State
#   Postal Code
#   Region
#   Product ID
#   Category
#   Sub-Category
#   Product Name
#   Sales

# %%
# TODO: Create total_spending per customer
# Hint: df.groupby('Customer ID')['Sales'].sum()
#
# Replace column names below with the actual names from your dataset.

# customer_spending = df.groupby('???')['???'].sum()
# customer_spending.name = 'total_spending'

# Your code here:
customer_spending = df.groupby('Customer Name')['Sales'].sum()
customer_spending.name = 'total_spending'
customer_spending
# Out:
# Customer Name
# Aaron Bergman          886.156
# Aaron Hawkins         1744.700
# Aaron Smayling        3050.692
# Adam Bellavance       7755.620
# Adam Hart             3250.337
#                         ...
# Xylona Preis          2374.658
# Yana Sorensen         6720.444
# Yoseph Carroll        5454.350
# Zuschuss Carroll      8025.707
# Zuschuss Donatelli    1493.944
# Name: total_spending, Length: 793, dtype: float64

# %%
# TODO: Create order_frequency per customer
# Hint: Count the number of rows (orders) per customer.
# Use .groupby(...).size() or .groupby(...)['some_col'].count()

# Your code here:
order_freq = df.groupby('Customer Name').size()
order_freq.name = 'order_frequency'
order_freq
# Out:
# Customer Name
# Aaron Bergman          6
# Aaron Hawkins         11
# Aaron Smayling        10
# Adam Bellavance       18
# Adam Hart             20
#                       ..
# Xylona Preis          28
# Yana Sorensen         12
# Yoseph Carroll         8
# Zuschuss Carroll      31
# Zuschuss Donatelli     9
# Name: order_frequency, Length: 793, dtype: int64

# %%
# TODO: Create avg_order_value per customer
# Hint: Use .groupby(...)['Sales'].mean()

# Your code here:
avg_order_value = df.groupby('Customer Name')['Sales'].mean()
avg_order_value.name = 'avg_order_value'
avg_order_value
# Out:
# Customer Name
# Aaron Bergman         147.692667
# Aaron Hawkins         158.609091
# Aaron Smayling        305.069200
# Adam Bellavance       430.867778
# Adam Hart             162.516850
#                          ...
# Xylona Preis           84.809214
# Yana Sorensen         560.037000
# Yoseph Carroll        681.793750
# Zuschuss Carroll      258.893774
# Zuschuss Donatelli    165.993778
# Name: avg_order_value, Length: 793, dtype: float64

# %%
# TODO: Combine all three into a single customer-level DataFrame
# Hint: Use pd.concat([series1, series2, series3], axis=1)
# or create them all at once with .groupby(...).agg(...)

# customer_summary = pd.concat([customer_spending, order_freq, avg_order], axis=1)
# customer_summary.columns = ['total_spending', 'order_frequency', 'avg_order_value']

# Your code here:
customer_summary = pd.concat([customer_spending, order_freq, avg_order_value], axis=1)
customer_summary.columns = ['total_spending', 'order_frequency', 'avg_order_value']
customer_summary
# Out:
#                     total_spending  order_frequency  avg_order_value
# Customer Name
# Aaron Bergman              886.156                6       147.692667
# Aaron Hawkins             1744.700               11       158.609091
# Aaron Smayling            3050.692               10       305.069200
# Adam Bellavance           7755.620               18       430.867778
# Adam Hart                 3250.337               20       162.516850
# ...                            ...              ...              ...
# Xylona Preis              2374.658               28        84.809214
# Yana Sorensen             6720.444               12       560.037000
# Yoseph Carroll            5454.350                8       681.793750
# Zuschuss Carroll          8025.707               31       258.893774
# Zuschuss Donatelli        1493.944                9       165.993778
#
# [793 rows x 3 columns]

# %%
# TODO: Display the first 10 rows of your customer summary and .describe()

# Your code here:
print(customer_summary.head(10))
print(customer_summary.describe())
# Out:
#                     total_spending  order_frequency  avg_order_value
# Customer Name
# Aaron Bergman              886.156                6       147.692667
# Aaron Hawkins             1744.700               11       158.609091
# Aaron Smayling            3050.692               10       305.069200
# Adam Bellavance           7755.620               18       430.867778
# Adam Hart                 3250.337               20       162.516850
# Adam Shillingsburg        3255.310               25       130.212400
# Adrian Barton            14473.571               20       723.678550
# Adrian Hane               1735.514               16       108.469625
# Adrian Shami                58.820                3        19.606667
# Aimee Bixby                966.710               12        80.559167
#        total_spending  order_frequency  avg_order_value
# count      793.000000       793.000000       793.000000
# mean      2851.520064        12.356873       227.402594
# ...

# %% [markdown]
# ---
# ## Task 6: Save Cleaned Data (TODO)
#
# Save the cleaned DataFrame to a new CSV file. Never overwrite the original.

# %%
# TODO: Save the cleaned main DataFrame
df.to_csv('superstore_cleaned.csv', index=False)

# TODO: Save the customer summary DataFrame
customer_summary.to_csv('customer_summary.csv')

# Your code here:

# %% [markdown]
# ---
# ## Reflection
#
# Answer these in a text cell or comments:
#
# 1. Why did we use median instead of mean for filling numerical missing values?
# 2. What is the difference between the row-level DataFrame (one row per order) and the customer-level summary? When would you use each?
# 3. If two rows have identical values in every column, are they always true duplicates? When might they not be?

# %% [markdown]
# 1. Median is less affected by extreme values
# 2. Row-level: One row = one order. Use for analyzing individual transactions, order patterns, daily operations.
# Customer-level: One row = one customer (aggregated data). Use for analyzing customer behavior, customer segmentation, total customer value.
# 3. Same customer placing the exact same order twice (legitimate)
# Different customers with same order details
# System recording errors
